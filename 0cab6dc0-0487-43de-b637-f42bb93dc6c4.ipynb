# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Мурат, привет!**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если это неприемлемо, то дай мне знать и мы перейдем на «вы».
#
# Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их отработки проект не будет принят. При проверке я обращаю внимание не только на код, но и на интерпретацию и анализ результатов, а также соответствие данных техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно делаешь, что не убираешь описание задачи. Это поможет быстро вспомнить, о чем проект, если ты к нему вернешься спустя какое-то время.
#
# Данный блок можно расширить при помощи плана работы и описания данных. Посмотреть подробнее про вступительный блок можно в разделе "Полезные инструкции в учебе" блока "Оформление проекта".
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Василий, привет! Спасибо за обратную связь, комментарии и замечания. Во время внесения поправок я старался учесть всё то, что ты объяснил. В некоторых блоках я не стал удалять старый код, просто закомментировал. Поэтому, примерный порядок будет такой:
# 1. Название блока
#    #мой закомментированный старый код
#    -мой новый код
#    -твои первые замечания по блоку.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Принято :)
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data.head()
data.tail()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 23694             3.7           5.0         73.3      3          NaN   False
# 23695             NaN           5.0         38.0      4          NaN   False
# 23696             NaN           3.0         29.7      1          NaN   False
# 23697             3.0          17.0          NaN     12          NaN   False
# 23698             2.5           5.0         12.3      1          NaN   False
#
#        open_plan  kitchen_area  balcony        locality_name  \
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Хорошей практикой является разделение импорта библиотек и выполнения основной логики кода, такой как загрузка данных, для лучшей читаемости и структурированности. Такое разделение помогает сделать код более понятным и удобным для других разработчиков или коллег, которые будут просматривать или использовать твой код.
#
# Разделение импортов и загрузки данных — это общепринятая хорошая практика, которой рекомендуется следовать
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Спасибо за замечание! Сделано
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
data.describe().astype('int')
# Out:
#        total_images  last_price  total_area  rooms  ceiling_height  \
# count         23699       23699       23699  23699           14504
# mean              9     6541548          60      2               2
# std               5    10887013          35      1               1
# min               0       12190          12      0               1
# 25%               6     3400000          40      1               2
# 50%               9     4650000          52      2               2
# 75%              14     6800000          69      3               2
# max              50   763000000         900     19             100
#
#        floors_total  living_area  floor  kitchen_area  balcony  \
# count         23613        21796  23699         21421    12180
# mean             10           34      5            10        1
# std               6           22      4             5        1
# min               1            2      1             1        0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Предупреждения перед графиками можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку matplotlib.pyplot as plt
# 2. В конец кода добавить `;`
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Спасибо за замечание! Сделано
# </div>

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Молодец, что не забываешь про явные дубликаты.
# </div>

# %% [markdown]
# Вывод:
# 1. Явных дубликатов нет
# 2. cityCenters_nearest не соответсвтует стилю snake_case
# 3. Столбец is_apartment должен содержать булевые значения. Кроме того, столбец first_day_exposition должен быть представлен в формате даты и времени.
# 4. При анализе данных обнаружены некоторые столбцы, которые вызывают сомнения в качестве данных. Например, в столбце ceiling_height максимальная высота потолка указана как 100 метров, и столбец room содержит значения с нулевым количеством комнат.
# 5. Большое количество пропусков

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Хорошая вводная часть.
#
# Рекомендую создать универсальную функцию, которая будет принимать на вход датафрейм, а на выходе она будет выводить всего нужные характеристики, например, head, describe, info, дубликаты и т.п.
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Сменим тип данных для is_apartment

# %%
data['is_apartment'] = data['is_apartment'].fillna(False) #замена осуществлена на False так как
#при отстутсвии апартаментов человек не заполнял данный столбец

# %%
data['is_apartment'] = data['is_apartment'].astype('bool') #замена типа данных на булев, так как
#в задании написано6 что это bool тип, к тому же этот столбец отвечает на вопрос это апартаменты или нет

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Все верно, либо это апартаменты, либо нет. Булев тип подходит лучше всего.
# </div>

# %%
data['is_apartment'].value_counts()
# Out:
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# #### Приведём формат даты и времени в столбце "first_day_exposition" к удобному для форматирования и обработки виду

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1             NaN          11.0         18.6      1         False   False
# 2             NaN           5.0         34.3      4         False   False
# 3             NaN          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 При чтении файла можно указать параметр `parse_dates: parse_dates=['date']`. Тогда пандас автоматически переведет список столбцов в даты. Пример можно посмотреть [здесь](https://newtechaudit.ru/gruzi-daty-krasivo/).
# </div>

# %% [markdown]
# #### Приведение названий столбцов к единому стилю

# %%
data = data.rename(columns={'cityCenters_nearest': 'city_centers_nearest', 
                            'parks_around3000': 'parks_around_3000', 
                            'ponds_around3000': 'ponds_around_3000'})
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1             NaN          11.0         18.6      1         False   False
# 2             NaN           5.0         34.3      4         False   False
# 3             NaN          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# #### Подсчитаем количество квартир с нулевым обозначением количества комнат в столбце "rooms"

# %%
data.query('rooms == 0')['rooms'].count()
# Out:
# 197

# %% [markdown]
# проверим, к каким данныи относятся 0 комнат

# %%
data.query('rooms == 0').head(10)
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 144             1   2450000.0       27.00           2017-03-30      0
# 349             4   2320000.0       25.00           2017-09-27      0
# 440             8   2480000.0       27.11           2018-03-12      0
# 508             0   3375000.0       34.40           2017-03-28      0
# 608             2   1850000.0       25.00           2019-02-20      0
# 697            12   2500000.0       24.10           2017-12-01      0
# 716             5   1500000.0       17.00           2017-06-07      0
# 780             9   2600000.0       26.10           2018-02-20      0
# 839            14   1900000.0       35.00           2017-04-14      0
# 946             5   2200000.0       23.00           2016-09-27      0
#
#      ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 144             NaN          24.0        15.50      2         False    True
# ...

# %% [markdown]
# Можно предположить, что при такой площади и отсутствии площади кухни, 0 комнат означает, что это квартиры-студии. В этом случае предположим, что ошибок в двнных нет

# %% [markdown]
# #### Проверка значений колонки "ceiling_height"

# %%
data.ceiling_height.sort_values(ascending=False).head(60)
# Out:
# 22869    100.00
# 22336     32.00
# 3148      32.00
# 21377     27.50
# 20478     27.00
# 5246      27.00
# 5807      27.00
# 10773     27.00
# 17857     27.00
# 22938     27.00
# 21824     27.00
# 4876      27.00
# 5669      26.00
# 18545     25.00
# 11285     25.00
# 355       25.00
# 6246      25.00
# 14382     25.00
# 4643      25.00
# 9379      25.00
# 5076      24.00
# 20507     22.60
# 17496     20.00
# 15061     14.00
# 22309     10.30
# 5863       8.30
# 15743      8.00
# 3474       8.00
# 17442      8.00
# 20264      6.00
# 21227      5.80
# 1388       5.60
# 7578       5.50
# 12628      5.30
# 1026       5.30
# 464        5.20
# 1053       5.00
# 21923      4.90
# 2802       4.80
# 1300       4.70
# 19142      4.70
# 12401      4.65
# 14519      4.50
# 6802       4.50
# 10159      4.50
# 2823       4.50
# 9783       4.50
# 3067       4.50
# 13224      4.50
# 7521       4.45
# 8018       4.45
# 11651      4.40
# 7274       4.40
# 6728       4.40
# 4201       4.37
# ...

# %%
data.ceiling_height.describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
data.ceiling_height.isna().sum()
# Out:
# 9195

# %% [markdown]
# Удаляем квартиры с высотой потолков от 4 до 25метров

# %%
data.drop(index=data.query('ceiling_height > 4 and ceiling_height < 25').index,inplace=True)

# %% [markdown]
# Для квартир с высотой потолков до 25 до 36 метров предполагаем, что это опечатка и делим на 10, получая 2.5 и 3.6 метра.

# %%
data.update(data[(data['ceiling_height'] >= 25) & (data['ceiling_height'] <= 36)]['ceiling_height']/10)

# %% [markdown]
# Удаляем квартиры с высотой потолков от 36 метров.

# %%
data.drop(index=data.query('ceiling_height > 36').index,inplace=True)

# %%
data.ceiling_height.isna().sum()
# Out:
# 9195

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1             NaN          11.0         18.6      1         False   False
# 2             NaN           5.0         34.3      4         False   False
# 3             NaN          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data.ceiling_height.describe()
# Out:
# count    14448.000000
# mean         2.720651
# std          0.258876
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max          4.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Приравняем невошедшие значения к среднему, т.к. потолков выше 4 м. и ниже 2,5 м. быть не может

# %%
data.drop(index=data.query('ceiling_height < 2.5').index,inplace=True)

# %%
ceiling_height_median = data['ceiling_height'].median()

# %%
print(ceiling_height_median)
# Out:
# 2.65

# %% [markdown]
# Заменяем пропуски медианным значением

# %%
data['ceiling_height'].loc[data['ceiling_height'].isna()] = ceiling_height_median
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
data.ceiling_height.isna().sum()
# Out:
# 0

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.65          11.0         18.6      1         False   False
# 2            2.65           5.0         34.3      4         False   False
# 3            2.65          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично справился, молодец. Верно. Потолки это довольно стандартизированная величина, поэтому пропуски можно безболезненно заменить их медианой.
# </div>

# %% [markdown]
# #### Выполним проверку столбца "floors_total" на отсутствующие значения

# %%
data.loc[data['floors_total'].isna()].head(10)
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 186             12  11640000.0       65.20           2018-10-02      2
# 237              4   2438033.0       28.10           2016-11-23      1
# 457              4   9788348.0       70.80           2015-08-01      2
# 671              4   6051191.0       93.60           2017-04-06      3
# 1757             5   3600000.0       39.00           2017-04-22      1
# 1930             1   9750000.0       66.77           2016-05-13      2
# 2392             7   5395770.0       53.00           2017-06-29      2
# 2846             4   2325000.0       27.80           2016-09-21      1
# 2952            10   6500000.0       54.30           2019-04-23      1
# 3031             9   6400000.0       56.70           2018-03-27      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 186             2.65           NaN        30.80      4         False   False
# ...

# %%
data['floors_total'].isna().sum()
# Out:
# 86

# %% [markdown]
# С учетом имеющейся выборки, не удается однозначно определить информацию о количестве этажей в доме на основе других параметров. Поэтому пока оставим эту информацию без изменений.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Доля пропусков здесь менее 5% и для экономии времени их можно удалить.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Спасибо за замечание! Сделано
# </div>

# %%
data.dropna(subset=['floors_total'], inplace=True)

# %%
data['floors_total'].isna().sum()
# Out:
# 0

# %%
data.floors_total = data.floors_total.astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23484 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23484 non-null  int64
#  1   last_price            23484 non-null  float64
#  2   total_area            23484 non-null  float64
#  3   first_day_exposition  23484 non-null  datetime64[ns]
#  4   rooms                 23484 non-null  int64
#  5   ceiling_height        23484 non-null  float64
#  6   floors_total          23484 non-null  int64
#  7   living_area           21626 non-null  float64
#  8   floor                 23484 non-null  int64
#  9   is_apartment          23484 non-null  bool
#  10  studio                23484 non-null  bool
#  11  open_plan             23484 non-null  bool
#  12  kitchen_area          21269 non-null  float64
#  13  balcony               12062 non-null  float64
# ...

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1858
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2215
# balcony                 11422
# locality_name              48
# airports_nearest         5493
# city_centers_nearest     5473
# parks_around_3000        5472
# parks_nearest           15498
# ponds_around_3000        5472
# ponds_nearest           14478
# days_exposition          3153
# dtype: int64

# %% [markdown]
# #### Проверка данных по столбцу "living_area"

# %%
data['living_area'].isna().sum()#кол-во пропусков
# Out:
# 1858

# %%
data['living_area'].describe()
# Out:
# count    21626.000000
# mean        34.369604
# std         21.674688
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %%
data.query('living_area < 5')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3242              7   4440000.0        41.0           2017-07-02      1
# 13915            20   6350000.0        52.0           2018-02-06      2
# 21758             0   2330000.0        23.0           2018-01-01      0
# 23574            14  64990000.0       139.0           2015-11-24      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 3242             2.65            17          3.0     17         False   False
# 13915            3.00             6          2.0      2         False   False
# 21758            2.65            24          2.0     22         False    True
# 23574            3.00             8          3.0      8         False   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 3242       False          11.0      NaN  Санкт-Петербург           19272.0
# ...

# %% [markdown]
# В датасете есть квартиры с жилой площадью 2 и 3 кв.м. Это неправдоподобно. Нельзя однозначно утверждать, какое значение следует использовать, мы можем предположить, что лучше сохранить остальные данные в массиве. Для этого мы заменим недопустимые значения на "None".

# %%
data.loc[data['living_area'] < 5, 'living_area'] = None

# %%
data['living_area'].isna().sum()
# Out:
# 1862

# %%
data.query('living_area < 5')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around_3000, parks_nearest, ponds_around_3000, ponds_nearest, days_exposition]
# Index: []

# %% [markdown]
# Мы успешно обработали недостоверные данные о жилой площади, однако в столбце существует множество пропусков. Удаление строк с другой важной информацией может исказить статистику, поэтому мы оставим строки с недостающими данными о площадях в неизменном состоянии.

# %% [markdown]
# #### Проверка данных по столбцу "kitchen_area". Согласно Снип, кухня не может быть менее 5 м2. Выполним выборку по данному значению:

# %%
data.query('kitchen_area < 5')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 76               12   2800000.0        55.1           2016-05-14      3
# 298               9   2650000.0        42.8           2017-04-25      2
# 422               8   1700000.0        55.2           2018-03-24      3
# 906              15   2600000.0        27.0           2017-07-10      1
# 1327              6   2650000.0        46.2           2016-12-01      2
# ...             ...         ...         ...                  ...    ...
# 22675             9   2600000.0        42.4           2017-08-18      2
# 22839            14   3350000.0        27.0           2018-11-03      1
# 22849             6   2380000.0        25.0           2016-03-22      1
# 23110             1   2900000.0        34.0           2018-02-01      2
# 23678            10   3500000.0        43.0           2016-05-19      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2215

# %% [markdown]
# Заполним пропущенные значения нулевыми, учитывая, что отсутствие данных о площади кухни связано с квартирами, в которых
# комнаты объединены с кухней, и площадь комнаты уже включает в себя площадь кухни.

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(0)

# %% [markdown]
# Вычислим среднее значение для кухни отсортировав "мусорные" значения

# %%
mean_area = data.query('kitchen_area > 5' and 'kitchen_area < 15')['kitchen_area'].mean()

# %% [markdown]
# Заменим ошибочные данные средним значением нашей выборки

# %%
data.loc[data['kitchen_area'] < 5, 'kitchen_area'] = mean_area

# %%
data.query('kitchen_area < 5')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around_3000, parks_nearest, ponds_around_3000, ponds_nearest, days_exposition]
# Index: []

# %% [markdown]
# #### Проверка данных по столбцу "balcony"

# %%
data['balcony'].isna().sum()
# Out:
# 11422

# %% [markdown]
# Имеем 50% процентов пропусков. Можно предположить, что такие пропуски имеют системную природу и не случайны. Рассмотрим смежные данные и связанные с ними информацию о пропущенных значениях в столбце "balcony".

# %%
data.loc[data['balcony'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# 8                20   2900000.0       33.16           2018-05-23      1
# 10                5   5050000.0       39.60           2017-11-16      1
# ...             ...         ...         ...                  ...    ...
# 23692             2   1350000.0       30.00           2017-07-07      1
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# Исходя из данных и их распределения, мы можем предположить, что пропущенные значения в столбце "balcony" означают отсутствие балкона. Поэтому мы можем безопасно заменить пропуски (NaN) нулями.

# %%
data['balcony']=data['balcony'].fillna(0).astype('int')

# %%
data['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Верно, люди не заполняют "не выгодные" для продажи квартиры характеристики.
# </div>

# %% [markdown]
# #### Проверка данных по столбцу "locality_name" на уникальность названий

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
data['locality_name'].value_counts().tail(20)
# Out:
# посёлок Белоостров                       1
# посёлок Сапёрное                         1
# деревня Трубников Бор                    1
# посёлок Петро-Славянка                   1
# деревня Большая Пустомержа               1
# поселок Сумино                           1
# деревня Нижняя                           1
# деревня Снегирёвка                       1
# поселок городского типа Большая Ижора    1
# деревня Каськово                         1
# поселок Каложицы                         1
# поселок Коробицыно                       1
# посёлок Пансионат Зелёный Бор            1
# посёлок Высокоключевой                   1
# поселок Севастьяново                     1
# поселок Гаврилово                        1
# поселок Усть-Луга                        1
# деревня Меньково                         1
# деревня Тойворово                        1
# деревня Реброво                          1
# Name: locality_name, dtype: int64

# %% [markdown]
# Приведём значения к нижнему регистру для избавления от дубликатов

# %%
data['locality_name'] = data['locality_name'].str.lower()

# %%
data['locality_name'].duplicated().sum()
# Out:
# 23120

# %% [markdown]
# Заменяем все "ё" на "е"

# %%
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')

# %%
data['locality_name'].unique()
# Out:
# array(['санкт-петербург', 'поселок шушары', 'городской поселок янино-1',
#        'поселок парголово', 'поселок мурино', 'ломоносов', 'сертолово',
#        'петергоф', 'пушкин', 'деревня кудрово', 'коммунар', 'колпино',
#        'поселок городского типа красный бор', 'гатчина',
#        'деревня федоровское', 'выборг', 'кронштадт', 'кировск',
#        'деревня новое девяткино', 'поселок металлострой',
#        'поселок городского типа лебяжье',
#        'поселок городского типа сиверский', 'поселок молодцово',
#        'поселок городского типа кузьмоловский',
#        'садовое товарищество новая ропша', 'павловск',
#        'деревня пикколово', 'всеволожск', 'волхов', 'кингисепп',
#        'приозерск', 'сестрорецк', 'деревня куттузи', 'поселок аннино',
#        'поселок городского типа ефимовский', 'поселок плодовое',
#        'деревня заклинье', 'поселок торковичи', 'поселок первомайское',
#        'красное село', 'поселок понтонный', 'сясьстрой', 'деревня старая',
# ...

# %% [markdown]
# заменяем "городской поселок" на "поселок городского типа"

# %%
data['locality_name'] = data['locality_name'].str.replace('городской поселок','поселок городского типа')

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично! Можно еще применить такой подход:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
# </div>

# %% [markdown]
#  Исследование значений столбца "is_apartment"

# %% [markdown]
# Вывод по предобработке данных:
# - Проведена предварительная обработка данных, включая оптимизацию типов данных и заполнение пропусков.
# - Заменили ошибочные данные средним значением нашей выборки по площади кухни.
# - Заменили тип данных для is_apartment.
# - Привели формат даты и времени в столбце "first_day_exposition" к удобному для форматирования и обработки виду
# - Привели названия столбцов к единому стилю.
# - Обработали недостоверные данные о жилой площади, однако в столбце существует множество пропусков. Удаление строк с другой важной информацией может исказить статистику, поэтому мы оставим строки с недостающими данными о площадях в неизменном состоянии.
# - Заменили неправдоподобные значения по столбцу ceiling_height на медианные
# - По столбцам city_centers_nearest, parks_around_3000, parks_nearest, ponds_around_3000, ponds_nearest, airports_nearest -   вероятно, пропуски возникли в связи с отсутствием информации на картографических данных. Зполнить их нечем, поэтому пропуски оставим.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# В общем и целом хорошая работа!
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Замечания:
#
# * Рассмотрены и объяснены не все столбцы с пропусками.
#
# * Обрати, пожалуйста, внимание на тип данных во floors_total, вряд ли он должен быть дробным.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# #### Цена одного квадратного метра

# %%
data['price_per_square_meter'] = data['last_price']/data['total_area']

# %%
data['price_per_square_meter'] = data['price_per_square_meter'].astype('int')

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          NaN      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['price_per_square_meter'].mean().round(1)
# Out:
# 99286.7

# %% [markdown]
# В контексте значительного разнообразия цен на квартиры, можно отметить, что средняя цена за квадратный метр составляет
# 100 тысяч рублей.

# %% [markdown]
# #### День недели публикации объявления

# %%
data['dayofweek'] = data['first_day_exposition'].dt.dayofweek

# %% [markdown]
# #### Месяц публикации объявления

# %%
data['month'] = data['first_day_exposition'].dt.month

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# На будущее: часто датафреймы содержат данные за разные годы. Чтобы корректно обработать месяцы и не объединить их из разных годов, можно рассмотреть такой метод `astype('datetime64[M]')`. При использовании этого метода не придется ссылаться на `pd.DatetimeIndex`.
#
# Рекомендую ознакомиться с этими материалами:
#
# [Работа с датами в Python]( https://pythobyte.com/how-to-work-with-dates-and-times-in-python-0a176355/)
#
# [Извлечение часов, минут и секунд из numpy datetime64](https://stackoverflow.com/questions/70901855/get-hour-and-minutes-and-seconds-from-numpy-datetime64)
#
# Попробуй использовать этот метод, когда агализируешь динамику по неделям, месяцам или годам.
#
# Пример применения:
#
#
# `df['first_day_exposition'].dt.date # конвертация в формат даты
# df['first_day_exposition'].astype('datetime64[M]')`
#
# Если даты в датафрейме из разных годов, то после преобразования месяцы будут отображаться как первый день каждого месяца, например '2019-05-01'.
#
# </div>

# %% [markdown]
# #### Год публикации объявления

# %%
data['year'] = data['first_day_exposition'].dt.year

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          NaN      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['year'].value_counts()
# Out:
# 2018    8440
# 2017    8120
# 2019    2862
# 2016    2749
# 2015    1177
# 2014     136
# Name: year, dtype: int64

# %% [markdown]
# Как видно из данных, количество недвижимости, предложенной на рынке, достигло пиковых значений в 2017 и 2018 годах. Однако в
# 2019 году количество предложений сократилось в четыре раза и вернулось к уровню, схожему с 2016 годом.

# %% [markdown]
# #### Тип этажа квартиры (значения — «первый», «последний», «другой»).

# %%
last_floor = data.query('floors_total/floor == 1')

# %%
data['group'] = data['floor']

# %%
data.loc[data['group'] == 1, 'group'] = 'Первый'

# %%
data.loc[last_floor.index, 'group'] = 'Последний'

# %%
data.loc[(data['group'] != 'Первый') & (data['group']!='Последний'), 'group'] = 'Другой'

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          NaN      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['group'].value_counts()
# Out:
# Другой       17292
# Последний     3319
# Первый        2873
# Name: group, dtype: int64

# %% [markdown]
# Кажется, что более востребованными являются квартиры, расположенные на любых этажах, за исключением первого и последнего.

# %% [markdown]
# Посчитаем и добавим в таблицу соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
data['attitude_liv/total']=(data['living_area']/data['total_area']).round(2)

# %%
data['attitude_kitch/total']=(data['kitchen_area']/data['total_area']).round(2)

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          NaN      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['attitude_liv/total'].mean().round(2)
# Out:
# 0.56

# %%
data['attitude_kitch/total'].mean().round(2)
# Out:
# 0.19

# %% [markdown]
# Согласно средним данным, площадь кухни составляет практически 20% от общей площади, в то время как жилая площадь составляет всего половину. Можно сделать вывод, что в основном на рынке преобладают 1-2 комнатные квартиры с относительно небольшой кухней.

# %% [markdown]
# Вывод: На основании проведенного анализа можно отметить следующее: активные продажи жилья начались с 2017 года, а предложения на первом и последнем этажах в сумме составляют менее трети от общего количества объявлений. В среднем, жилая площадь предлагаемых квартир составляет всего половину от общей площади, в то время как площадь кухни составляет около 20% от общей площади. При этом средняя цена за квадратный метр достигает отметки в 100 тысяч рублей.

# %% [markdown]
# #### Расстояние до центра города в километрах

# %%
data['city_centers_nearest_km'] = round(data['city_centers_nearest'] / 1000)

# %%
data.head(4)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          NaN      9         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 0      False     25.000000        0  санкт-петербург           18863.0
# 1      False     11.000000        2   поселок шушары           12817.0
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично! Приступим к исследовательскому анализу.
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# Площадь:

# %%
#print('Диаграмма размаха площади квартиры')
#data.boxplot(column=['total_area'], figsize=(10,5), grid=True)
#plt.ylabel('Площадь квартиры в метрах')
#plt.show()

# %%
#data['total_area'].describe()

# %% [markdown]
# Отсечем выбросы

# %%
#good_data = data.query('total_area < 100')

# %%
#print('Диаграмма размаха площади квартиры после отсечения выбивающихся значений')
#good_data.boxplot(column=['total_area'], figsize=(9,5), grid=True)
#plt.ylabel('площадь квартиры в квадратных метрах')
#plt.show()

# %%
#import numpy as np
#from matplotlib import pyplot as plt

# %%
#good_data.sort_values(by='total_area', ascending=True).plot(kind='hist', y='total_area',title='Распределение предложений квартир по площади',bins=100, figsize=(15,5), grid=True)

#plt.xlabel('Площадь квартиры в кв.м')
#plt.ylabel('Количество предложений')
#plt.show()

# %% [markdown]
# Цена:

# %%
#print('Диаграмма размаха цены предложений')
#good_data.boxplot('last_price')
#plt.ylabel('цена на момент снятия с публикации')
#plt.show()

# %% [markdown]
# Отсечем выбросы

# %%
#good_data = good_data.query('last_price < 9000000')

# %%
#good_data.plot(kind='hist', y='last_price', title='Распределение предложений квартир по цене',grid=True, bins=50, figsize=(15,5))
#plt.ylabel('количество предложений')
#plt.xlabel('цена на момент снятия с публикации')
#plt.show()

# %% [markdown]
# Число комнат:

# %%
#good_data.plot(kind='hist',y='rooms',title='Распределение предложений по количеству комнат',grid=True, bins=50, figsize=(5,8))
#plt.xlabel('Количество комнат')
#plt.ylabel('Количество предложений')
#plt.show()

# %% [markdown]
# Высота потолков:

# %%
#print('Диаграмма размаха высоты потолков')
#good_data.boxplot(column=['ceiling_height'], figsize=(8,5), grid=True)

#plt.ylabel('Высота потолков')
#plt.show()

# %% [markdown]
# Основываясь на графике "ящика с усами", отбросим квартиры с потолками свыше 2,9 метра, а так же ниже 2,4

# %%
#good_data = good_data.query('ceiling_height < 2.9 and ceiling_height > 2.4')
#good_data.plot(kind='hist',y='ceiling_height',grid=True, bins=10, figsize=(10,5),title='Распределение предложений по высоте потолков')
#plt.xlabel('Высота потолоков')
#plt.ylabel('Количество предложений')
#plt.show()

# %% [markdown]
# Вывод: Исходя из проведенного анализа данных о площади, ценах, количестве комнат и высоте потолков, можно с уверенностью утверждать, что подавляющее большинство объявлений о продаже квартир относится к категории 1-2 комнатных квартир, представленных на рынке по цене около 4 миллионов рублей и с высотой потолков в среднем 2,65 метра.

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# На следующей строке я начал новый код.</div>

# %% [markdown]
# #### Общая площадь

# %%
data['total_area'].describe()
# Out:
# count    23484.000000
# mean        60.203354
# std         35.062554
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %%
# Рассчитаем Q1, Q3 и IQR чтобы построить график без выбросов
q1 = data['total_area'].quantile(.25) # первый квартиль Q1
q3 = data['total_area'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR

# Построим гистограмму площади
data['total_area'].hist(bins=30, range=((q1 - 1.5 * iqr), (q3 + 1.5 * iqr)), figsize=(10, 8), ec='black', legend=True)
plt.title('Общая площадь')
plt.xlabel('м²')
plt.ylabel('недвижимость')
plt.show()

# %% [markdown]
# В рассматриваемом диапазоне площадей примерно до 115 м², после исключения выбросов, наблюдается следующая характеристика. Большинство объектов недвижимости имеют площадь в диапазоне от 30 до 70 м², и наиболее часто встречающаяся площадь составляет около 45 м². Объекты с площадью более 100 м² встречаются редко, а объекты с площадью менее 30 м² также представлены в небольшом количестве.
#
# Среднее значение площади составляет около 60 м², и медианное значение (половина объектов имеет меньшую площадь, а другая половина - большую) равно 52 м². Эти значения смещены в сторону больших площадей из-за наличия нескольких крупных объектов недвижимости, которые редки, но влияют на среднее значение, делая его выше медианы. Это приводит к "растянутому" виду графика площадей.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Верно, с большей площадью меньше предложений. Объекты выше 90-100 кв. м - это более дорогой сегмент.
# </div>

# %% [markdown]
# #### Жилая площадь

# %%
data['living_area'].describe()
# Out:
# count    21622.000000
# mean        34.375500
# std         21.672356
# min          5.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %%
# Рассчитаем Q1, Q3 и IQR чтобы построить график без выбросов
q1 = data['living_area'].quantile(.25) # первый квартиль Q1
q3 = data['living_area'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR

# Построим гистограмму площади
data['living_area'].hist(bins=30, range=((q1 - 1.5 * iqr), (q3 + 1.5 * iqr)), figsize=(10, 8), ec='black', legend=True)
plt.title('Жилая площадь')
plt.xlabel('м²')
plt.ylabel('Недвижимость')
plt.show()

# %% [markdown]
# В рассматриваемом диапазоне жилой площади примерно до 78 м², после исключения выбросов, наблюдаются следующие особенности. Большинство объектов недвижимости имеют жилую площадь в пределах 15-43 м², и наиболее часто встречающаяся площадь составляет около 17 м². Объекты с жилой площадью более 60 м² встречаются редко, а объекты с площадью менее 17 м² также представлены в небольшом количестве.
#
# Среднее значение жилой площади составляет около 34 м², а медианное значение (половина объектов имеет меньшую площадь, а другая половина - большую) равно 30 м². Эти значения смещены в сторону больших площадей из-за наличия нескольких крупных объектов недвижимости, которые, хоть и редки, влияют на среднее значение и создают "хвост" на графике из-за их больших площадей.

# %% [markdown]
# #### Площадь кухни

# %%
data['kitchen_area'].describe()
# Out:
# count    23484.000000
# mean        10.329755
# std          5.627517
# min          5.000000
# 25%          7.500000
# 50%          9.000000
# 75%         11.402500
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
# Рассчитаем Q1, Q3 и IQR чтобы построить график без выбросов
q1 = data['kitchen_area'].quantile(.25) # первый квартиль Q1
q3 = data['kitchen_area'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR

# Построим гистограмму площади
data['kitchen_area'].hist(bins=30, range=((q1 - 1.5 * iqr), (q3 + 1.5 * iqr)), figsize=(10, 8), ec='black', legend=True)
plt.title('Площадь кухни')
plt.xlabel('м²')
plt.ylabel('Недвижимость')
plt.show()

# %% [markdown]
# В рассматриваемом диапазоне площади кухонь примерно до 17 м², после исключения выбросов, наблюдаются следующие особенности. Большинство кухонь имеют  площадь в пределах 6-12 м², и наиболее часто встречающаяся площадь составляет около 8 м². Кухни с  площадью более 12 м² встречаются редко, а кухни с площадью менее 6 м² также представлены в небольшом количестве.
#
# Среднее значение площади составляет около 10 м², а медианное значение (половина объектов имеет меньшую площадь, а другая половина - большую) равно 9 м².

# %% [markdown]
# #### Цена объекта

# %%
data['last_price'].describe()
# Out:
# count    2.348400e+04
# mean     6.499655e+06
# std      1.074179e+07
# min      1.219000e+04
# 25%      3.420000e+06
# 50%      4.650000e+06
# 75%      6.773322e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
# Рассчитаем Q1, Q3 и IQR чтобы построить график без выбросов
q1 = data['last_price'].quantile(.25) # первый квартиль Q1
q3 = data['last_price'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR

# Построим гистограмму цены
data['last_price'].hist(bins=30, range=(0, (q3 + 1.5 * iqr)), figsize=(10, 8), ec='black', legend=True)
plt.title('Цена')
plt.xlabel('10 млн руб.')
plt.ylabel('Недвижимост')
plt.show()

# %% [markdown]
# В рассматриваемом диапазоне цен до примерно 12 миллионов рублей, после исключения выбросов, наблюдаются следующие характеристики. Большинство объектов недвижимости имеют цену в диапазоне от 3 до 5 миллионов рублей, и наиболее часто встречающаяся цена составляет около 3,5 миллиона рублей. Варианты с ценой более 10 миллионов рублей встречаются редко.
#
# Среднее значение цены составляет около 6,5 миллиона рублей, а медианное значение (цена, которая делит набор данных пополам) равно 4,6 миллиона рублей. Эти значения смещены в сторону более высоких цен из-за наличия нескольких крупных объектов недвижимости, которые, хоть и редки, влияют на среднее значение и создают небольшой "хвост" на графике из-за своих высоких цен.

# %% [markdown]
# #### Количество комнат

# %%
data['rooms'].describe()
# Out:
# count    23484.000000
# mean         2.069239
# std          1.076423
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
# Рассчитаем Q1, Q3 и IQR чтобы построить график без выбросов
q1 = data['rooms'].quantile(.25) # первый квартиль Q1
q3 = data['rooms'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR

# Построим гистограмму кол-ва комнат
data['rooms'].hist(bins=5, range=(1, (q3 + 1.5 * iqr)), figsize=(10, 8), ec='black', legend=True)
plt.title('Количество комнат объекта недвижимости')
plt.xlabel('комнаты')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# В рассматриваемом диапазоне количества комнат от 1 до 5, после исключения некорректных значений (0 комнат) и выбросов, наблюдаются следующие характеристики. Большинство объектов недвижимости имеют 1 или 2 комнаты, и немного меньше объектов имеют 3 комнаты. Объектов с 4 или 5 комнатами относительно немного.
#
# Среднее и медианное значение количества комнат составляют 2 комнаты. Редкие значения, такие как объекты с количеством комнат от 6 до 19, не оказывают существенного влияния на среднее значение, поскольку их количество невелико и они представляют собой аномалии.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍Однокомнатные популярней по ряду причин: цена(доступней для одиноких людей, а также людям в гражданском браке), рентабельность(покупка с целью продать дороже, а так же сдача в наём для приезжих, студентов и т.д), наследство.
# </div>

# %% [markdown]
# #### Высота потолков

# %%
data['ceiling_height'].describe()
# Out:
# count    23484.000000
# mean         2.694478
# std          0.204276
# min          2.500000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          4.000000
# Name: ceiling_height, dtype: float64

# %%
# Рассчитаем Q1, Q3 и IQR для построения графика без выбросов
q1 = data['ceiling_height'].quantile(.25) # первый квартиль Q1
q3 = data['ceiling_height'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR


# Построим гистограмму высоты потолков
data['ceiling_height'].hist(bins=10, range=((q1 - 1.5 * iqr), (q3 + 1.5 * iqr)), figsize=(10, 8), ec='black', legend=True)
plt.title('Высота потолков')
plt.xlabel('метры (м)')
plt.ylabel('Недвижимость')
plt.show()

# %% [markdown]
# В расматриваемом диапазоне высот потолков от 2,5 до 2,85 метров, после исключения неправильных значений и выбросов, можно выделить следующие характеристики. Большинство объектов недвижимости имеют высоту потолков в пределах 2,5 метра и 2,65 метра, и наиболее часто встречающиеся значения находятся в этом диапазоне. Реже встречаются варианты с высотой потолков от 2,7 метра до 2,85 метра.
#
# Среднее значение высоты потолков составляет примерно 2,7 метра, и медианное значение равно 2,65 метра.

# %% [markdown]
# #### Тип этажа квартиры («первый», «последний», «другой»)

# %%
data['floor'].describe()
# Out:
# count    23484.000000
# mean         5.884304
# std          4.879045
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %%
q1 = data['floor'].quantile(.25) # первый квартиль Q1
q3 = data['floor'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR


# Построим гистограмму этажа квартиры
data['floor'].hist(bins=10, range=(1, (q3 + 1.5 * iqr)), figsize=(10, 8), ec='black', legend=True)
plt.title('Этаж квартир')
plt.xlabel('этаж')
plt.ylabel('Недвижимость')
plt.show()

# %% [markdown]
# В рассматриваемом диапазоне этажей от 1 до 16, после исключения некорректных значений и выбросов, можно выделить следующие характеристики. Большинство объектов недвижимости находятся на этажах с 1 по 4, и наиболее часто встречающиеся этажи находятся в этом диапазоне. Варианты с этажами от 4 до 7 встречаются реже.
#
# Среднее значение этажа составляет примерно 5,8, и медианное значение (центральное значение в выборке) равно 4

# %%
#Проверка столбца с категоризацией по типу квартиры
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          NaN      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['group'].describe()
# Out:
# count      23484
# unique         3
# top       Другой
# freq       17292
# Name: group, dtype: object

# %%
#кол-во в каждой категории
data['group'].value_counts()
# Out:
# Другой       17292
# Последний     3319
# Первый        2873
# Name: group, dtype: int64

# %%
#посторим гистограмму
data['group'].value_counts().plot.bar(figsize=(5, 3), ec='black', legend=True)
plt.show()

# %% [markdown]
# Из графика видно, что недвижимость, находящаяся на первом и последнем этажах, имеет примерно схожие значения, и их доля на рынке не так велика. Основная часть объектов находится между первым и последним этажами.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Да, чаще всего продают не последний и не первый этажи - такие этажи могут быть проблемными (заглядывают прохожие, холодно, жарко, протекает крыша и т.д.)
#
# Также это связано с этажностью строительства. Первый и последний этажи - это лишь по одному этажу, а группа "другой" включает в себя все этажи, кроме первого и последнего. Для 3-этажных домов мы бы увидели равномерное распределение, но строительство заметно выше, чем 3 этажа.
# </div>

# %% [markdown]
# #### Общее количество этажей в доме

# %%
data['floors_total'].describe()
# Out:
# count    23484.000000
# mean        10.693451
# std          6.600202
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
q1 = data['floor'].quantile(.25) # первый квартиль Q1
q3 = data['floor'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR


# Построим гистограмму общего кол-ва этажей в доме
data['floors_total'].hist(bins=10, range=(1, (q3 + 1.5 * iqr)), figsize=(10, 8), ec='black', legend=True)
plt.title('Общее количество этажей в доме')
plt.xlabel('этаж')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# Рассматриваемый диапазон этажей находится в пределах от 1 до 16 этажей, с учетом исключения некорректных значений и выбросов. В большинстве случаев объекты недвижимости представлены в виде 5- и 10-этажных зданий, в то время как другие варианты этажности встречаются реже. Среднее значение этажности составляет 10 этажей, и медианное значение равно 9 этажам.

# %% [markdown]
# #### Расстояние до центра города в метрах

# %%
data['city_centers_nearest'].describe()
# Out:
# count    18011.000000
# mean     14202.091777
# std       8610.991352
# min        181.000000
# 25%       9252.000000
# 50%      13105.000000
# 75%      16293.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %%
q1 = data['city_centers_nearest'].quantile(.25) # первый квартиль Q1
q3 = data['city_centers_nearest'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR

# Построим гистограмму этажа квартиры
data['city_centers_nearest'].hist(bins=20, range=((q1 - 1.5 * iqr), (q3 + 1.5 * iqr)), figsize=(10, 8), ec='black', legend=True)
plt.title('Расстояние до центра города в метрах')
plt.xlabel('м')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# Анализ проводился в пределах диапазона расстояния от центра, который составляет от примерно 1000 до примерно 26000 метров, с исключением некорректных значений и выбросов. Большинство объектов недвижимости находятся на расстоянии приблизительно 11-16 километров от центра. Другие варианты удаленности встречаются реже. Среднее значение удаленности составляет 14,2 километра, а медианное значение равно примерно 13 километрам.

# %% [markdown]
# #### Расстояние до ближайшего парка

# %%
data.head(3)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 0      False          25.0        0  санкт-петербург           18863.0
# 1      False          11.0        2   поселок шушары           12817.0
# 2      False           8.3        0  санкт-петербург           21741.0
#
#    city_centers_nearest  parks_around_3000  parks_nearest  ponds_around_3000  \
# ...

# %%
data['parks_nearest'].describe()
# Out:
# count    7986.000000
# mean      490.683446
# std       342.050921
# min         1.000000
# 25%       288.000000
# 50%       454.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %%
q1 = data['parks_nearest'].quantile(.25) # первый квартиль Q1
q3 = data['parks_nearest'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR


# Построим гистограмму этажа квартиры
data['parks_nearest'].hist(bins=15, range=(1, (q3 + 1.5 * iqr)), figsize=(10, 8), ec='black', legend=True)
plt.title('Расстояние до ближайшего парка')
plt.xlabel('м')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# Рассматриваемый диапазон расстояния от объектов недвижимости до ближайшего парка охватывает значения от 0 до 1100 метров. Бльшинство объектов недвижимости расположены на растоянии от ближайшего парка в диапазоне от 400 до примерно 600 метров. Самый ближайший объект к парку находится на расстоянии 500 метров. Среднее расстояние до парка составляет 490 метров, а медианное значение равно 454 метрам. Эти данные позволяют сделать вывод о том, что большинство объектов недвижимости находятся на относительно близком расстоянии от ближайших парков, что может быть важным фактором при оценке их привлекательности для покупателей.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Мурат, я прошу тебя строго придерживаться шагов ТЗ. В исследовательской части нам необходимо для каждого из предложенных параметров построить визуализацию, посмотреть аномалии и сделать вывод под каждым параметром. Прошу тебя реализовать.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Василий, ты прав. Спасибо за уместное замечание. Это всё моя невнимательность. Первоначальный код я не удалял, просто закомментировал и написал заново.</div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ### Изучение времени продажи квартиры

# %%
#good_data.head()

# %%
#print('Диаграмма размаха времени продажи квартиры')
#good_data.boxplot('days_exposition')
#plt.ylabel('Время продажи квартиры')
#plt.show()

# %% [markdown]
# Отбросми значения свыше 250, чтобы не портить статистику

# %%
#good_data = good_data.query('days_exposition < 250')

# %%
#good_data['days_exposition'].agg(['mean','median'])

# %%
#good_data.plot(kind='hist',y='days_exposition',title='Распределение количества продаж по времени', bins=100, figsize=(10,5))
#plt.xlabel('Сколько дней было размещено объявление (от публикации до снятия)')
#plt.ylabel('Количество объявлений')
#plt.show()

# %% [markdown]
# Среднее время продажи среднестатистической квартиры составляет примерно 2-3 месяца и может изменяться в зависимости от различных факторов, таких как площадь, цена и расстояние до центра.

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# На следующей строке я начал новый код.</div>

# %%
q1 = data['days_exposition'].quantile(.25) # первый квартиль Q1
q3 = data['days_exposition'].quantile(.75) # третий квартиль Q3
iqr = q3 - q1 # межквартильный размах IQR

# Построим гистограмму времени продажи квартиры
data['days_exposition'].hist(bins=100, range=(0, (q3 + 1.5 * iqr)), figsize=(7, 5), ec='black', legend=True)
plt.title('Время продажи квартиры')
plt.xlabel('дни')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# На графике заметны выраженные пики в районе примерно 45-60 дней, но для получения более четкой картины и избегания искажений, мы ограничим период времени до 100 дней.

# %%
data['days_exposition'].hist(bins=100, range=(0, 100), figsize=(7, 5), ec='black', legend=True)
plt.title('Время продажи объекта квартиры')
plt.xlabel('дни')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# Исходя из графика, наиболее часто продажи квартир занимают около 45 и 60 дней. Однако важно учитывать, что это не всегда означает, что квартира действительно продана в указанный срок. Многие объявления могут закрываться по истечении срока публикации, несмотря на то, что квартира ещё не продана. Также существует вероятность, что объявление остаётся на сайте даже после фактической продажи недвижимости.

# %%
data['days_exposition'].describe()
# Out:
# count    20331.000000
# mean       180.709458
# std        219.555450
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Cреднее время продажи недвижимости составляет примерно 181 день, в то время как медианное значение составляет 95 дней. Максимальное время продажи достигает 1580 дней. Чтобы более наглядно оценить распределение времени продажи, необходимо построить диаграмму размаха.

# %%
data.boxplot(column='days_exposition', figsize=(8, 6))
plt.title('Размах времени продажи объекта недвижимости')
plt.ylim(-100, 600)
plt.ylabel('дни')
plt.show()

# %% [markdown]
# Вывод: Есть большой разброс по времени продажи, среднее значение почти в 2 раза больше медианно. Отвечая на впрос "Какие продажи можно считать быстрыми, а какие — необычно долгими?" можно сказать: быстрая продажа - менее 45 дней, обычная продажа - от 45 до 231 дней, долгая продажа - от 231 до 510 дней. Все продажи, занимающие более 510 дней, были рассмотрены как выбросы.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Немного не так, чтобы ответить на вопрос "Какие продажи можно считать быстрыми, а какие — необычно долгими?" лучше посмотреть на распределение данные с помощью boxplot() или describe(). Ориентироваться лучше на Q1.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Василий, ты прав. Спасибо за уместное замечание. Первоначальный код я не удалял, просто закомментировал и написал заново.</div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Верно
# </div>

# %% [markdown]
# ### Какие факторы больше всего влияют на общую (полную) стоимость объекта?

# %%
#good_data['city_centers_nearest'] = good_data['city_centers_nearest']/1000

# %%
#(good_data
    
#     .pivot_table(index='last_price', values=['total_area','rooms','city_centers_nearest'])
#     .plot(style='o',grid=True, figsize=(12, 5), title='График зависимости цены от площади, числа комнат, удалённости от центра')
#)
#plt.xlabel('Цена на момент снятия с публикации')
#plt.ylabel('Удалённость от центра\n Число комнат\n Площадь')
#plt.show()

# %% [markdown]
# Проанализируем зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.

# %%
#(good_data
#     .pivot_table(index='group', values='last_price').sort_values(by='last_price', ascending=True)
#     .plot(grid=True, figsize=(9, 5),linewidth=3, title='Зависимость цены от этажа расположения квартиры')
#)
#plt.xlabel('Этаж расположения квартиры')
#plt.ylabel('Цена')
#plt.show()

# %%
#good_data.pivot_table(index='group',values='last_price',aggfunc='count').plot.pie(y='last_price', figsize=(7,7), label='', title='График количественного отношения распределения предложений в зависимости от этажа')
#plt.show()

# %% [markdown]
# По данным графикам видно, что квартиры на любых этажах, за исключением первого и последнего, более востребованы как с точки зрения цены, так и по количеству предложений на рынке. Кроме того, заметно, что цена недвижимости зависит от её удаленности от центра и общей площади квартиры - чем ближе к центру и чем больше площадь, тем выше цена. Однако, в случае количества комнат, изменение цены не так значительно.

# %% [markdown]
# Проанализируем зависимость цены от даты размещения: дня недели, месяца и года.

# %%
#(good_data
    
#     .pivot_table(index='dayofweek', values=['last_price'])
#     .plot(grid=True, figsize=(10, 5),linewidth=3,title='Зависимость цены от даты размещения')
#)
#plt.xlabel('День размещения')
#plt.ylabel('Цена')

#plt.show()

# %%
#(good_data
    
#     .pivot_table(index='month', values=['last_price'])
#     .plot(grid=True, figsize=(10, 5),linewidth=3, title='Зависимость цены от месяца размещения')
#)
#plt.xlabel('Месяц размещения')
#plt.ylabel('Цена')

#plt.show()

# %%
#(good_data
    
#     .pivot_table(index='year', values=['last_price'])
#     .plot(grid=True, figsize=(10, 5),linewidth=3,title='зависимость цены от года размещения')
     
#)
#plt.xlabel('Год размещения')
#plt.ylabel('Цена')

#plt.show()

# %% [markdown]
# На графиках видно, что объявления, размещенные до четверга, имеют в среднем более высокие цены, чем те, которые размещены в другие дни недели. Кроме того, на графике по месяцам хорошо заметны два периода, когда цены на недвижимость падают - это середина и конец года, и в эти месяцы, возможно, не самое выгодное время для продажи недвижимости. Средняя стоимость предложений снижается в эти периоды. С точки зрения годовой динамики, заметно снижение цен на недвижимость с 2015 по 2017 годы, а с 2018 года наблюдается резкий рост, что, возможно, связано с увеличенным спросом на рынке недвижимости.

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# На следующей строке я начал новый код.</div>

# %% [markdown]
# #### Анализ зависимости цены от обшей площади

# %%
data.plot(x='total_area', y='last_price',\
                  style='.', title='Зависимость цены от общей площади',\
                  alpha=0.05, grid=True, sharex=False)
plt.show()

# %%
data.sort_values('total_area').plot(x='total_area', y='last_price',\
    style='-', title='Зависимость цены от общей площади')
plt.show()

# %%
data.pivot_table(index='total_area', values='last_price')\
.plot(style='-',title='Зависимость средней цены от общей площади', figsize=(10,4))
plt.show()

# %%
print('Коэффициент корреляции цены от общей площади', round(data['total_area'].corr(data['last_price']), 2))
# Out:
# Коэффициент корреляции цены от общей площади 0.65

# %% [markdown]
# На графике, отображающем зависимость средней цены от общей площади, мы видим, что для квартир с площадью до примерно 120 квадратных метров цены имеют минимальное распределение и варьируются незначительно. Средний разброс цен наблюдается в диапазоне от 120 до 180 квадратных метров, где цены могут различаться более значительно. Однако наибольший разброс цен заметен для квартир с площадью свыше 180 квадратных метров. Коэффициент корреляции между общей площадью и ценой составляет 0.65, что подтверждает наличие сильной положительной зависимости между этими двумя переменными.

# %% [markdown]
# #### Анализ зависимости цены от жилой площади

# %%
data.pivot_table(index='living_area', values='last_price')\
.plot(style='-',title='Зависимость средней цены от жилой площади', figsize=(10,4))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Коэффициент корреляции цены от жилой площади', round(data['living_area'].corr(data['last_price']), 2))
# Out:
# Коэффициент корреляции цены от жилой площади 0.56

# %% [markdown]
# Коэффициент корреляции показывает, что зависимость между ценой и жилой площадью не является сильной. На графике наблюдается более явная связь между этими параметрами для жилой площади в диапазоне от 10 до примерно 60 квадратных метров. Однако для значений жилой площади вне этого диапазона цены подвержены большему разбросу.

# %% [markdown]
# #### Анализ зависимости цены от площади кухни

# %%
data.pivot_table(index='kitchen_area', values='last_price')\
.plot(style='-',title='Зависимость средней цены от площади кухни', figsize=(10,4))
plt.show;

# %%
print('Коэффициент корреляции цены от площади кухни', round(data['kitchen_area'].corr(data['last_price']), 2))
# Out:
# Коэффициент корреляции цены от площади кухни 0.43

# %% [markdown]
# Из графика и вычисления коэффициента корреляции видно, что взаимосвязь между ценой и площадью кухни является незначительной.

# %% [markdown]
# #### Анализ зависимости цены от количества комнат

# %%
data.pivot_table(index='rooms', values='last_price')\
.plot(style='-',title='Зависимость средней цены от количества комнат', figsize=(10,4))
plt.show;

# %%
print('Коэффициент корреляции цены от количества комнат', round(data['rooms'].corr(data['last_price']), 2))
# Out:
# Коэффициент корреляции цены от количества комнат 0.36

# %% [markdown]
# В данном случае, коэффициент корреляции между ценой и количеством комнат равный 0,36 говорит о том, что существует
# положительная корреляция между этими переменными, но она не очень сильная.

# %% [markdown]
# #### Анализ зависимости цены от этажа, на котором расположена квартира (первый, последний, другой)

# %%
data.pivot_table(index='floor', values='last_price')\
.plot(style='-',title='Зависимость средней цены от этажа', figsize=(10,4))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Коэффициент корреляции цены от этажа', round(data['floor'].corr(data['last_price']), 2))
# Out:
# Коэффициент корреляции цены от этажа 0.03

# %%
data.pivot_table(index='group', values='last_price', aggfunc='median')
# Out:
#            last_price
# group
# Другой      4848500.0
# Первый      3900000.0
# Последний   4300000.0

# %%
data.pivot_table(index='group', values='last_price', aggfunc=('median'))\
.plot(style='-',title='Зависимость средней цены от типа этажа', figsize=(10,4), kind='bar')
plt.show();

# %%
# Для лучшей визуализации данных, будем использовать логарифмическую шкалу.
data.pivot_table(index='group', values='last_price', aggfunc=('median'))\
.plot(style='-',title='Зависимость средней цены от типа этажа', figsize=(10,4), kind='bar', logy=True)
plt.show();

# %% [markdown]
# Из анализа медианных значений видно, что первые этажи имеют самую низкую стоимость, а также цена на последние этажи ниже, чем на других этажах в зданиях.

# %% [markdown]
# #### Анализ зависимости цены от даты размещения (день недели, месяц, год)

# %%
data.pivot_table(index='dayofweek', values='last_price')\
.plot(style='-',title='Зависимость средней цены от дня недели размещения объявления', figsize=(10,4))
plt.show;

# %%
print('Коэффициент корреляции цены от дня недели размещения объявления', round(data['dayofweek'].corr(data['last_price']), 2))
# Out:
# Коэффициент корреляции цены от дня недели размещения объявления 0.0

# %% [markdown]
# Зависимости цены от дня размещения нет

# %%
data.pivot_table(index='month', values='last_price')\
.plot(style='-',title='Зависимость средней цены от месяца размещения объявления', figsize=(10,4))
plt.show;

# %%
print('Коэффициент корреляции цены от месяца размещения объявления', round(data['month'].corr(data['last_price']), 2))
# Out:
# Коэффициент корреляции цены от месяца размещения объявления 0.0

# %% [markdown]
# Зависимости цены от месяца размещения нет

# %%
data.pivot_table(index='year', values='last_price')\
.plot(style='-',title='Зависимость средней цены от года размещения объявления', figsize=(10,4))
plt.show;

# %%
print('Коэффициент корреляции цены от года размещения объявления', round(data['year'].corr(data['last_price']), 2))
# Out:
# Коэффициент корреляции цены от года размещения объявления -0.04

# %% [markdown]
# Вывод: Цена сильно зависит от общей и жилой площади, незначительно завист от площади кухни и количества комнат, и вообще
# не зависит от даты размещения.

# %% [markdown]
# Зависимости цены от года размещения нет

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Также, немного отошли от ТЗ. Здесь нам необходимо рассмотреть основные параметры: общую площадь, жилую площадь, площади кухни, количества комнат, остальные ты рассмотрел, но для этих нам необходимо построить визуализацию, например, диаграмму рассеивания, а также посчитать значения корреляций, для поиска зависимости.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Верная интерпретация полученных данных.
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 📝
# На рассмотренных выше параметров коэффициент корреляции Пирсона работал хорошо. Но применение его к остальным параметрам - типу этажа, дню недели, году, и месяцу - не эффективно, т.к. цена квартиры зависит от них не линейно.
#
# Также, в качестве визуализации для **основных** параметров больше подойдет диаграмма рассеивания.
# </div>

# %% [markdown]
# ### Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений — постройте сводную таблицу с количеством объявлений и средней ценой квадратного метра для этих населенных пунктов. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра

# %% [markdown]
# #### 10 населённых пунктах с наибольшим числом объявлений

# %%
data_top_10 = data.pivot_table(index='locality_name', values=['first_day_exposition'], aggfunc='count').sort_values(by='first_day_exposition', ascending=False).head(10)
data_top_10.columns=['number_of_ads']
data_top_10
# Out:
#                    number_of_ads
# locality_name
# санкт-петербург            15569
# поселок мурино               552
# поселок шушары               439
# всеволожск                   396
# пушкин                       365
# колпино                      337
# поселок парголово            326
# гатчина                      307
# деревня кудрово              299
# выборг                       234

# %% [markdown]
# "Санкт-Петербург" безусловно является лидером по количеству размещенных объявлений о продаже недвижимости. В то же время, остальные населенные пункты, входящие в ТОП-10, размещены в области города и имеют примерно схожее количество объявлений.

# %% [markdown]
# #### Средняя цена квадратного метра в этих населённых пунктах.

# %%
data_top_10['cost_per_meter_mean'] = data.pivot_table(index='locality_name', values='price_per_square_meter', aggfunc='mean')
data_top_10_s=data_top_10.style.format({'cost_per_meter_mean':'{:.2f} ₽'})

# %%
data_top_10_s
# Out:
# <style  type="text/css" >
# </style><table id="T_7b943_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >number_of_ads</th>        <th class="col_heading level0 col1" >cost_per_meter_mean</th>    </tr>    <tr>        <th class="index_name level0" >locality_name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7b943_level0_row0" class="row_heading level0 row0" >санкт-петербург</th>
#                         <td id="T_7b943_row0_col0" class="data row0 col0" >15569</td>
#                         <td id="T_7b943_row0_col1" class="data row0 col1" >114661.48 ₽</td>
#             </tr>
#             <tr>
#                         <th id="T_7b943_level0_row1" class="row_heading level0 row1" >поселок мурино</th>
#                         <td id="T_7b943_row1_col0" class="data row1 col0" >552</td>
# ...

# %% [markdown]
# Наши результаты показывают, что самые низкие цены на жилье в ТОП-10 находятся в Выборге и Всеволожске, в то время как Санкт-Петербург занимает первое место с небольшим отрывом от Пушкина.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# К сожалению здесь код упал с ошибкой. Прошу тебя поправить и прислать проект на повторное ревью.
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 📝
# Таблица верна. Совет: на общие продажи лучше смотреть через призму медианы. Она более устойчива к выбросам.
#
# Также хорошо бы визуализировать получаемую информацию.
#
# </div>

# %% [markdown]
# ### Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города — постройте график изменения средней цены для каждого километра от центра Петербурга.

# %%
data_spb = data.query('locality_name == "санкт-петербург"')

# %%
data_spb.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0       108.0           2019-03-07      3
# 2             10   5196000.0        56.0           2015-08-20      2
# 3              0  64900000.0       159.0           2015-07-24      3
# 4              2  10000000.0       100.0           2018-06-19      2
# 7              5   7915000.0        71.6           2019-04-18      2
# 9             18   5400000.0        61.0           2017-02-26      3
# 10             5   5050000.0        39.6           2017-11-16      1
# 15            16   4650000.0        39.0           2017-11-18      1
# 16            11   6700000.0        82.0           2017-11-23      3
# 17             6   4180000.0        36.0           2016-09-09      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0             2.70            16         51.0      8         False   False
# ...

# %%
len(data_spb)
# Out:
# 15569

# %%
(
data_spb
    .pivot_table(index='city_centers_nearest_km', values='price_per_square_meter')
    .plot(marker='o', grid=True, figsize=(8, 6), legend=False, xlim=(0, 30))
)
plt.title('Средняя цена квадратного метра\nс шагом в 1 км до центра')
plt.xlabel('км')
plt.ylabel('руб./м²')
plt.show();

# %% [markdown]
# В процессе анализа обнаружена очевидная тенденция: средняя стоимость недвижимости уменьшается при увеличении расстояния от центра. Особенно заметен резкий подъем цен в самом центре, на расстоянии от 0 до 2 км. Важно отметить снижение цен на расстоянии около 3 км. Кроме того, можно выделить второй пик роста цен, который наблюдается на расстоянии около 27 км.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Верно, дальше от центра - дешевле квартиры.
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В заключении проведенной работы по подготовке и анализу данных, можно сделать следующие ключевые выводы:
#
# В ходе предобработки данных мы столкнулись с большим количеством пропусков в различных столбцах. Некоторые из них мы заполнили средними значениями, чтобы не потерять основной объем данных, в то время как другие оставили без изменений с пропущенными значениями.
#
# После очистки данных от "мусорных" и выбивающихся значений, мы провели ряд операций, включая подсчет средней стоимости квадратного метра жилья, вычисление стоимости каждого километра удаления от центра, выделение сегмента квартир в центре города и анализ их характеристик, а также провели статистический анализ скорости продажи объявлений и ее зависимости от различных факторов.
#
# В процессе анализа данных с использованием графиков было выявлено, что лидером по размещению объявлений о продаже недвижимости является Санкт-Петербург. Несмотря на это, средняя цена квадратного метра в городе практически такая же, как и в области.
#
# Большинство объектов недвижимости имеют площадь в диапазоне от 30 до 70 м², и наиболее часто встречающаяся площадь составляет около 45 м². Большинство объектов недвижимости имеют цену в диапазоне от 3 до 5 миллионов рублей, и наиболее часто встречающаяся цена составляет около 3,5 миллиона рублей. Большинство объектов недвижимости имеют 1 или 2 комнаты, и немного меньше объектов имеют 3 комнаты. Большинство объектов недвижимости находятся на этажах с 1 по 4, и наиболее часто встречающиеся этажи находятся в этом диапазоне. Наиболее часто продажи квартир занимают около 45 и 60 дней.Цена сильно зависит от общей и жилой площади, незначительно завист от площади кухни и количества комнат, и вообще не зависит от даты размещения.
#
# Таким образом, на основе анализа данных можно сделать вывод, что сегодняшние покупатели предпочитают жилье с определенными характеристиками, и это важно учитывать при размещении объявлений о продаже недвижимости.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# Ты очень серьезно подходишь к визуализации.
#
# Вот пара ссылок на полезные источники:https://habr.com/ru/company/otus/blog/540526/, https://pythonru.com/biblioteki/seaborn-plot
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# Мурат, замечательная работа, ты мыслишь нестандартно, это отличный навык, который у тебя уже есть, ты последователен и вдумчив. Твою работу очень интересно читать и проверять.
#
# Я готов принять твой проект и если у тебя не осталось каких-либо вопросов, то пришли свой проект на повторное ревью и он будет принят 😊

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Василий, спасибо! Очень приятно слышать это! На самом деле, именно визуализация мне ддается очень тяжело. Код переписывал
# несколько десятков раз, спасало только бесконечное гугление и чтение конспектов прошлых уроков. Не могу четко понять логику
# и  запомнмить алгоритм. Поэтому вопрос - может ты подскажешь какой-нибудь секрет как это сделать? Или тренажер, может
# что-то еще. Буду признателен! И, еще раз спасибо за обратную связь, советы и дополнительные ссылки!.</div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Что касается визуализаций, то дальше по курсу будет много практики с этим, ну, а так, можно найти много источников в интернете, но лучше пока не забегать вперед.
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
#
# Мурат, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
